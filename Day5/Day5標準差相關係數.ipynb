# %%
import numpy as np

# %%
english_score = np.array([55,89,76,65,48,70])
math_score = np.array([60,85,60,68,np.nan,60])
chinese_score = np.array([65,90,82,72,66,77])

# %%
#1. 請計算各科成績平均、最大值、最小值、標準差，其中數學缺一筆資料可忽略?

#2. 第五位同學補考數學後成績為55，請計算補考後數學成績平均、最大值、最小值、標準差?

#3. 用補考後資料找出與國文成績相關係數最高的學科?

# %%
np.average(english_score), np.nanmax(english_score), np.nanmin(english_score), np.nanstd(english_score)
# Out:
# (67.16666666666667, 89, 48, 13.433995020924426)

# %%
np.average(math_score), np.nanmax(math_score), np.nanmin(math_score), np.nanstd(math_score)
# Out:
# (nan, 85.0, 60.0, 9.707728879609279)

# %%
np.average(chinese_score), np.nanmax(chinese_score), np.nanmin(chinese_score), np.nanstd(chinese_score)
# Out:
# (75.33333333333333, 90, 65, 8.825468196582484)

# %%
#2. 第五位同學補考數學後成績為55，請計算補考後數學成績平均、最大值、最小值、標準差?

# %%
math_score_6people=np.array([60,85,60,68,55,60])

# %%
np.average(math_score_6people), np.nanmax(math_score_6people), np.nanmin(math_score_6people), np.nanstd(math_score_6people)
# Out:
# (64.66666666666667, 85, 55, 9.860132971832694)

# %%
#3. 用補考後資料找出與國文成績相關係數最高的學科?

# %%
np.corrcoef(chinese_score, math_score_6people)
# Out:
# array([[1.        , 0.74056803],
#        [0.74056803, 1.        ]])

# %%
np.corrcoef(chinese_score, english_score)
# Out:
# array([[1.        , 0.97792828],
#        [0.97792828, 1.        ]])

# %%
#國文與英文相關係數較高
