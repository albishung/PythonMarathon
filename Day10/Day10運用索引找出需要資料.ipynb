# %%
import pandas as pd

# %%
#讀取STOCK_DAY_0050_202009.csv、STOCK_DAY_0050_202010.csv

# %%
Data1=pd.read_csv('STOCK_DAY_0050_202009.csv')

# %%
Data2=pd.read_csv('STOCK_DAY_0050_202010.csv')

# %%
#串聯

# %%
Data3=pd.concat([Data1,Data2],axis=1)

# %%
Data3
# Out:
#          date    open    high     low   close       date    open    high  \
# 0   109/09/01  102.45  103.35  101.85  103.35  109/10/05  103.45  104.05
# 1   109/09/02  103.65  104.05  102.30  103.00  109/10/06  104.00  104.35
# 2   109/09/03  103.70  104.30  103.20  103.30  109/10/07  104.00  105.00
# 3   109/09/04  102.00  102.70  101.90  102.55  109/10/08  105.45  106.35
# 4   109/09/07  102.55  103.05  101.90  102.40  109/10/12  106.70  107.70
# 5   109/09/08  102.75  103.10  102.45  103.00  109/10/13  107.35  107.60
# 6   109/09/09  101.75  102.35  101.15  102.30  109/10/14  107.05  107.20
# 7   109/09/10  102.80  103.35  102.60  103.20  109/10/15  106.50  106.50
# 8   109/09/11  103.20  103.35  102.80  103.25  109/10/16  105.70  106.30
# 9   109/09/14  103.50  104.55  103.25  104.55  109/10/19  105.65  106.60
# 10  109/09/15  104.45  105.20  104.25  104.95  109/10/20  106.40  106.45
# 11  109/09/16  106.55  107.00  106.35  106.55  109/10/21  106.00  106.55
# ...

# %%
#找出open小於close的資料

# %%
Data3.loc((Data3.open<Data3.close),['open','close'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-df04dacb821b> in <module>
# ----> 1 Data3.loc((Data3.open<Data3.close),['open','close'])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other)
#     699         axis = 1  # only relevant for Series other case
#     700
# --> 701         self, other = _align_method_FRAME(self, other, axis, level=None, flex=False)
#     702
#     703         # See GH#4537 for discussion of scalar op behavior
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in _align_method_FRAME(left, right, axis, flex, level)
#     508                 left, right = left.align(right, join="outer", level=level, copy=False)
#     509             else:
# --> 510                 raise ValueError(
#     511                     "Can only compare identically-labeled DataFrame objects"
# ...
